# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib

# %%
print("Numpy version : ",np.__version__)
print("Pandas Version : ",pd.__version__)
print("Seaborn version : ",sns.__version__)
print("Matplotlib version : ",matplotlib.__version__)
# Out:
# Numpy version :  1.18.1
# Pandas Version :  1.0.1
# Seaborn version :  0.10.0
# Matplotlib version :  3.1.3

# %%
data=pd.read_csv("creditcard.csv")

# %%
data.head(10)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 5   2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 6   4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708 -0.005159
# 7   7.0 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 8   7.0 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818  0.370145
# 9   9.0 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761  0.651583
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# ...

# %%
data.shape
# Out:
# (284807, 31)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
data.dtypes
# Out:
# Time      float64
# V1        float64
# V2        float64
# V3        float64
# V4        float64
# V5        float64
# V6        float64
# V7        float64
# V8        float64
# V9        float64
# V10       float64
# V11       float64
# V12       float64
# V13       float64
# V14       float64
# V15       float64
# V16       float64
# V17       float64
# V18       float64
# V19       float64
# V20       float64
# V21       float64
# V22       float64
# V23       float64
# V24       float64
# V25       float64
# V26       float64
# V27       float64
# V28       float64
# Amount    float64
# Class      object
# dtype: object

# %%
data.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.919560e-15  5.688174e-16 -8.769071e-15  2.782312e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552563e-15  2.010663e-15 -1.694249e-15 -1.927028e-16 -3.137024e-15
# ...

# %%
(data==np.nan).tail(10)
# Out:
#          Time     V1     V2     V3     V4     V5     V6     V7     V8     V9  \
# 284797  False  False  False  False  False  False  False  False  False  False
# 284798  False  False  False  False  False  False  False  False  False  False
# 284799  False  False  False  False  False  False  False  False  False  False
# 284800  False  False  False  False  False  False  False  False  False  False
# 284801  False  False  False  False  False  False  False  False  False  False
# 284802  False  False  False  False  False  False  False  False  False  False
# 284803  False  False  False  False  False  False  False  False  False  False
# 284804  False  False  False  False  False  False  False  False  False  False
# 284805  False  False  False  False  False  False  False  False  False  False
# 284806  False  False  False  False  False  False  False  False  False  False
#
#         ...    V21    V22    V23    V24    V25    V26    V27    V28  Amount  \
# ...

# %%
data.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
data["Amount"].describe()
# Out:
# count    284807.000000
# mean         88.349619
# std         250.120109
# min           0.000000
# 25%           5.600000
# 50%          22.000000
# 75%          77.165000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
plt.boxplot(data["V10"])
plt.show()

# %%
# sns.lineplot(data=data,x='Time',y='Amount')

# %%
x=np.array(data['Time'][:100])
y=np.array(data['Amount'][:100])

# %%
sns.lineplot(data=data,x=x,y=y)

# %%
data[data.duplicated()]
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 33          26.0 -0.529912  0.873892  1.347247  0.145457  0.414209  0.100223
# 35          26.0 -0.535388  0.865268  1.351076  0.147575  0.433680  0.086983
# 113         74.0  1.038370  0.127486  0.184456  1.109950  0.441699  0.945283
# 114         74.0  1.038370  0.127486  0.184456  1.109950  0.441699  0.945283
# 115         74.0  1.038370  0.127486  0.184456  1.109950  0.441699  0.945283
# ...          ...       ...       ...       ...       ...       ...       ...
# 282987  171288.0  1.912550 -0.455240 -1.750654  0.454324  2.089130  4.160019
# 283483  171627.0 -1.464380  1.368119  0.815992 -0.601282 -0.689115 -0.487154
# 283485  171627.0 -1.457978  1.378203  0.811515 -0.603760 -0.711883 -0.471672
# 284191  172233.0 -2.667936  3.160505 -3.355984  1.007845 -0.377397 -0.109730
# 284193  172233.0 -2.691642  3.123168 -3.339407  1.017018 -0.293095 -0.167054
#
# ...

# %%
#data[data.duplicated()].count()

# %%
(data["Amount"].duplicated()).value_counts()
# Out:
# True     252040
# False     32767
# Name: Amount, dtype: int64

# %%
#data['Amount']

# %%
#a=(filter(lambda x:x==True,data['Amount'].duplicated()))

# %%
#data["Amount"][a]

# %%
count_dupl=(data['Amount'].duplicated())==False

# %%
data[count_dupl].duplicated().value_counts()
# Out:
# False    32767
# dtype: int64

# %%
data_dupl=data.duplicated().value_counts()
plt.hist(data_dupl)
sns.countplot(data.duplicated().value_counts())

# %%
print(data.isnull().any())
# Out:
# Time      False
# V1        False
# V2        False
# V3        False
# V4        False
# V5        False
# V6        False
# V7        False
# V8        False
# V9        False
# V10       False
# V11       False
# V12       False
# V13       False
# V14       False
# V15       False
# V16       False
# V17       False
# V18       False
# V19       False
# V20       False
# V21       False
# V22       False
# V23       False
# V24       False
# V25       False
# V26       False
# V27       False
# V28       False
# Amount    False
# Class     False
# dtype: bool

# %%
print(data.isnull().all())
# Out:
# Time      False
# V1        False
# V2        False
# V3        False
# V4        False
# V5        False
# V6        False
# V7        False
# V8        False
# V9        False
# V10       False
# V11       False
# V12       False
# V13       False
# V14       False
# V15       False
# V16       False
# V17       False
# V18       False
# V19       False
# V20       False
# V21       False
# V22       False
# V23       False
# V24       False
# V25       False
# V26       False
# V27       False
# V28       False
# Amount    False
# Class     False
# dtype: bool

# %%
data1=data.drop_duplicates()

# %%
data1
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
len(data)
# Out:
# 284807

# %%
len(data1)
# Out:
# 283726

# %%
len(data)-len(data1)
# Out:
# 1081

# %%
data["Class"].value_counts()
# Out:
# '0'    284315
# '1'       492
# Name: Class, dtype: int64

# %%
count_1=data["Class"]=="'1'"

# %%
data[count_1]
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 541        406.0 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623        472.0 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 4920      4462.0 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
# 6108      6986.0 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536
# 6329      7519.0  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
count_1500=data["Amount"]>1500

# %%
data[count_1500]["Class"].value_counts()
# Out:
# '0'    1331
# '1'       3
# Name: Class, dtype: int64

# %%
data2=data[count_1500]

# %%
sns.lmplot(x='V1', y='Amount', data=data2,
           fit_reg=False, 
           hue='Class')

# %%
sns.scatterplot(x='Class',y='Amount',data=data[count_1500])

# %%
plt.hist(data2["Amount"],density=True,bins=40)
# Out:
# (array([8.97455583e-04, 3.12374043e-04, 1.61145340e-04, 1.20239215e-04,
#         6.69372949e-05, 2.97499088e-05, 2.10728521e-05, 7.43747721e-06,
#         7.43747721e-06, 7.43747721e-06, 7.43747721e-06, 2.47915907e-06,
#         2.47915907e-06, 0.00000000e+00, 2.47915907e-06, 0.00000000e+00,
#         0.00000000e+00, 2.47915907e-06, 1.23957954e-06, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         1.23957954e-06, 0.00000000e+00, 1.23957954e-06, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.23957954e-06]),
#  array([ 1501.5   ,  2106.2415,  2710.983 ,  3315.7245,  3920.466 ,
#          4525.2075,  5129.949 ,  5734.6905,  6339.432 ,  6944.1735,
#          7548.915 ,  8153.6565,  8758.398 ,  9363.1395,  9967.881 ,
# ...

# %%
d
# Out:
# 164        3828.04
# 865        1602.99
# 1027       1528.90
# 1281       1736.00
# 1388       2452.03
#             ...
# 281611     3670.00
# 283315     2992.05
# 283395     3820.86
# 283643     1601.20
# 284249    10199.44
# Name: Amount, Length: 1334, dtype: float64

# %%
data2
# Out:
#             Time        V1         V2         V3        V4         V5  \
# 164        103.0 -6.093248 -12.114213  -5.694973  3.294389  -1.413792
# 865        656.0 -1.789835  -5.835768  -1.472791 -0.851160  -2.433875
# 1027       775.0 -3.900810  -3.098370  -0.213428 -2.678434  -2.927576
# 1281       990.0 -2.960339  -4.268302  -0.959247  0.342961  -5.319277
# 1388      1077.0 -3.936794  -3.670519  -1.453820  2.299750  -9.749440
# ...          ...       ...        ...        ...       ...        ...
# 281611  170302.0 -5.034683 -12.155822  -4.527769  2.219104  -4.375383
# 283315  171514.0 -2.740984  -2.586374  -5.803083 -0.812563 -10.954787
# 283395  171560.0 -6.519366 -10.723215  -4.631726  0.074792  -9.973646
# 283643  171759.0 -1.069643  -5.946056  -1.265560  2.010759  -3.136595
# 284249  172273.0 -9.030538 -11.112584 -16.233798  3.592021 -40.427726
#
#                V6         V7        V8        V9  ...       V21       V22  \
# ...
